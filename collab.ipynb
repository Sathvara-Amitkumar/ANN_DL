# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathvara-Amitkumar/ANN_DL/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit tensorflow scikit-learn pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 93.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 110.3 MB/s eta 0:00:00

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANN"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANN

# %%
# !ls
# Out:
# app.py	      collab.ipynb  iris_model.h5	   scaler.pkl
# basics.ipynb  encoder.pkl   iris_prediction.ipynb

# %%
# !head -10 app.py
# Out:
# import streamlit as st
# import numpy as np
# import tensorflow as tf
# import joblib
#
# st.set_page_config(
#     page_title="🌸 Iris Flower Classification",
#     page_icon="🌸",
#     layout="centered"
# )

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3HDGBfLKM00x5nobDNY3yfhaE8M_5aYwz1KUnnu5Rf2zKxiyG")
public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://mousy-overtly-carless.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !streamlit run "app.py" --server.port 8501 &
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-07-30T11:10:54+0000 lvl=warn msg="failed to open private leg" id=c3939eca551c privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-07-30T11:10:54+0000 lvl=warn msg="failed to open private leg" id=a9474c7b559a privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# ...
#
# 2026-07-30 11:10:56.103 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.187.225.196:8501
#
# 2026-07-30 11:10:58.730062: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
